# %%
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('mysolutionsdatas.csv')
df
# Out:
#     Unnamed: 0  dfs_solutions  bfs_solutions  bf_solutions
# 0            0       0.003003       0.057052      2.014337
# 1            1       0.004004       0.057052      2.402690
# 2            2       0.004004       0.057052      2.624892
# 3            3       0.005004       0.057052      2.683946
# 4            4       0.006006       0.057052      4.759358
# ..         ...            ...            ...           ...
# 87          87       0.045041       0.067061     21.083233
# 88          88       0.046042       0.067061     23.135294
# 89          89       0.047043       0.067061     23.193347
# 90          90       0.047043       0.068063     23.410674
# 91          91       0.048044       0.068063     23.794043
#
# [92 rows x 4 columns]

# %%
fig = plt.figure(figsize=(15,9))
ax = fig.add_subplot()
Unemployment_Rate = [9.8,12,8,7.2,6.9,7,6.5,6.2,5.5,6.3]
  
ax.plot(df.dfs_solutions*1000,df.index, color='red',label = 'Depth-first search')
ax.plot(df.bfs_solutions*1000,df.index, color='blue',label = 'Breadth-first search')

ax.set_xlabel('Time spent (ms)', fontsize=20,font = 'Times new roman')
ax.set_ylabel('Solutions found',fontsize=20,font = 'Times new roman')

ax.set_yticks(range(0,93,10))
ax.set_xticks(range(0,int(df.bfs_solutions.max()*1000),10),fontsize= 18)
plt.yticks(fontsize = 16,font = 'Times New Roman')
plt.xticks(fontsize = 16,font = 'Times New Roman')

ax.legend(fontsize= 16)
ax.grid()

# %%
fig = plt.figure(figsize=(15,9))
ax = fig.add_subplot()
Unemployment_Rate = [9.8,12,8,7.2,6.9,7,6.5,6.2,5.5,6.3]
  
ax.plot(df.bf_solutions,df.index, color='red',label = 'Brute force')

ax.set_xlabel('Time spent (s)', fontsize=20,font = 'Times new roman')
ax.set_ylabel('Solutions found',fontsize=20,font = 'Times new roman')

ax.set_yticks(range(0,93,10))
ax.set_xticks(range(0,round(df.bf_solutions.max())+1),fontsize= 18)
plt.yticks(fontsize = 16,font = 'Times New Roman')
plt.xticks(fontsize = 16,font = 'Times New Roman')

ax.legend(fontsize= 16)
ax.grid()
